# %%
# Import required libraries for EDA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('TIDY_unclean.csv')
df = data.copy()
# Out:
# C:\Users\agspi\AppData\Local\Temp\ipykernel_41496\3111570511.py:1: DtypeWarning: Columns (35,36,37,38,39,40,41,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('TIDY_unclean.csv')

# %%
df.head()
# Out:
#                           projectid                  teacher_acctid_x  \
# 0  316ed8fb3b81402ff6ac8f721bb31192  42d43fa6f37314365d08692e08680973
# 1  90de744e368a7e4883223ca49318ae30  864eb466462bf704bf7a16a585ef296a
# 2  32943bb1063267de6ed19fc0ceb4b9a7  37f85135259ece793213aca9d8765542
# 3  bb18f409abda2f264d5acda8cab577a9  2133fc46f951f1e7d60645b0f9e48a6c
# 4  24761b686e18e5eace634607acbcc19f  867ff478a63f5457eaf41049536c47cd
#
#                            schoolid  school_ncesid  school_latitude  \
# 0  c0e6ce89b244764085691a1b8e28cb81   6.362701e+10        36.576340
# 1  d711e47810900c96f26a5d0be30c446d   4.837020e+11        32.911179
# 2  665c3613013ba0a66e3a2a26b89f1b68   4.103270e+11        45.166039
# 3  4f12c3fa0c1cce823c7ba1df57e90ccb   3.600153e+11        40.641727
# 4  10179fd362d7b8cf0e89baa1ca3025bb   6.227100e+10        34.043939
#
#    school_longitude  school_city school_state  school_zip school_metro  ...  \
# ...

# %%
df['date_posted'].min(), df['date_posted'].max()
# Out:
# ('2002-09-13', '2014-05-12')

# %%
df.describe(include='all').T
# Out:
#                         count  unique                               top freq  \
# projectid              664098  664098  316ed8fb3b81402ff6ac8f721bb31192    1
# teacher_acctid_x       664098  249555  787720cc575e3204991b8ca18d312d2b  266
# schoolid               664098   57004  9231edfbd3aa42675e70e69aea8b0a36  944
# school_ncesid        621362.0     NaN                               NaN  NaN
# school_latitude      664098.0     NaN                               NaN  NaN
# ...                       ...     ...                               ...  ...
# total_item_quantity  663773.0     NaN                               NaN  NaN
# total_item_cost      663773.0     NaN                               NaN  NaN
# unique_vendor_count  663773.0     NaN                               NaN  NaN
# num_items            663773.0     NaN                               NaN  NaN
# avg_cost_per_item    655757.0     NaN                               NaN  NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664098 entries, 0 to 664097
# Data columns (total 65 columns):
#  #   Column                                          Non-Null Count   Dtype
# ---  ------                                          --------------   -----
#  0   projectid                                       664098 non-null  object
#  1   teacher_acctid_x                                664098 non-null  object
#  2   schoolid                                        664098 non-null  object
#  3   school_ncesid                                   621362 non-null  float64
#  4   school_latitude                                 664098 non-null  float64
#  5   school_longitude                                664098 non-null  float64
#  6   school_city                                     664098 non-null  object
#  7   school_state                                    664098 non-null  object
#  8   school_zip                                      664094 non-null  float64
# ...

# %%
cols = set()
for i in df.columns:
    cols.add(i)

# %%
print(cols)
# Out:
# {'three_or_more_non_teacher_referred_donors', 'school_nlns', 'great_chat', 'eligible_double_your_impact_match', 'essay', 'resource_type', 'students_reached', 'secondary_focus_subject', 'short_description', 'title', 'essay_length', 'school_city', 'total_item_quantity', 'price_per_student', 'need_statement', 'teacher_prefix', 'school_latitude', 'is_exciting', 'school_magnet', 'fully_funded', 'teacher_acctid_y', 'school_district', 'total_item_cost', 'eligible_almost_home_match', 'teacher_referred_count', 'at_least_1_teacher_referred_donor', 'need_statement_length', 'fulfillment_labor_materials', 'school_year_round', 'teacher_ny_teaching_fellow', 'teacher_teach_for_america', 'school_county', 'num_items', 'school_charter_ready_promise', 'at_least_1_green_donation', 'school_longitude', 'school_zip', 'projectid', 'secondary_focus_area', 'primary_focus_subject', 'total_price_excluding_optional_support', 'school_kipp', 'schoolid', 'poverty_level', 'non_teacher_referred_count', 'school_ncesid'
# ...

# %%
df['fully_funded_binary'].value_counts()
# Out:
# fully_funded_binary
# 1.0    430683
# 0.0    188643
# Name: count, dtype: int64

# %%
simple_df = pd.DataFrame()
simple_df['projectid'] = df['projectid']

# %%
simple_df['fully_funded_binary'] = df['fully_funded_binary']

# %%
simple_df.head()
# Out:
#                           projectid  fully_funded_binary
# 0  316ed8fb3b81402ff6ac8f721bb31192                  NaN
# 1  90de744e368a7e4883223ca49318ae30                  NaN
# 2  32943bb1063267de6ed19fc0ceb4b9a7                  NaN
# 3  bb18f409abda2f264d5acda8cab577a9                  NaN
# 4  24761b686e18e5eace634607acbcc19f                  NaN

# %%
simple_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664098 entries, 0 to 664097
# Data columns (total 2 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   projectid            664098 non-null  object
#  1   fully_funded_binary  619326 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 10.1+ MB

# %%
simple_df.describe(include='all').T
# Out:
#                         count  unique                               top freq  \
# projectid              664098  664098  316ed8fb3b81402ff6ac8f721bb31192    1
# fully_funded_binary  619326.0     NaN                               NaN  NaN
#
#                          mean       std  min  25%  50%  75%  max
# projectid                 NaN       NaN  NaN  NaN  NaN  NaN  NaN
# fully_funded_binary  0.695406  0.460236  0.0  0.0  1.0  1.0  1.0

# %%
simple_df['fully_funded_binary'] = simple_df['fully_funded_binary'].fillna(0)

# %%
simple_df.describe().T
# Out:
#                         count      mean       std  min  25%  50%  75%  max
# fully_funded_binary  664098.0  0.648523  0.477432  0.0  0.0  1.0  1.0  1.0

# %%
simple_df['essay_length'] = df['essay_length']

# %%
simple_df['is_exciting'] = df['is_exciting']

# %%
simple_df['total_price_including_optional_support'] = df['total_price_including_optional_support']

# %%
simple_df.head()
# Out:
#                           projectid  fully_funded_binary  essay_length  \
# 0  316ed8fb3b81402ff6ac8f721bb31192                  0.0        2274.0
# 1  90de744e368a7e4883223ca49318ae30                  0.0        1290.0
# 2  32943bb1063267de6ed19fc0ceb4b9a7                  0.0        1263.0
# 3  bb18f409abda2f264d5acda8cab577a9                  0.0        1705.0
# 4  24761b686e18e5eace634607acbcc19f                  0.0        2385.0
#
#   is_exciting  total_price_including_optional_support
# 0         NaN                                  653.89
# 1         NaN                                  348.79
# 2         NaN                                  506.93
# 3         NaN                                  677.73
# 4         NaN                                  480.47

# %%
simple_df['is_exciting'].value_counts()
# Out:
# is_exciting
# f    582616
# t     36710
# Name: count, dtype: int64

# %%
simple_df['is_exciting'].isna().sum()
# Out:
# 44772

# %%
44772+36710+582616
# Out:
# 664098

# %%
#simple_df.to_csv('simple_featureMatrix.csv', index=False)

# %%
simple_df['date_posted'] = df['date_posted']

# %%
simple_df.head()
# Out:
#                           projectid  fully_funded_binary  essay_length  \
# 0  316ed8fb3b81402ff6ac8f721bb31192                  0.0        2274.0
# 1  90de744e368a7e4883223ca49318ae30                  0.0        1290.0
# 2  32943bb1063267de6ed19fc0ceb4b9a7                  0.0        1263.0
# 3  bb18f409abda2f264d5acda8cab577a9                  0.0        1705.0
# 4  24761b686e18e5eace634607acbcc19f                  0.0        2385.0
#
#   is_exciting  total_price_including_optional_support date_posted
# 0         NaN                                  653.89  2014-05-12
# 1         NaN                                  348.79  2014-05-12
# 2         NaN                                  506.93  2014-05-11
# 3         NaN                                  677.73  2014-05-11
# 4         NaN                                  480.47  2014-05-11

# %%
simple_df_test = simple_df[simple_df['is_exciting'].isna()].sort_values(by='date_posted')

# %%
simple_df_test.head()
# Out:
#                               projectid  fully_funded_binary  essay_length  \
# 44771  16bf6f4c3c37da1cb2e92ee8ce834510                  0.0        1303.0
# 44520  0a12b2441c416d4e1062527b70842ead                  0.0        1739.0
# 44521  a2185f29e1c5d568810eaac1ef8ebf67                  0.0        2537.0
# 44522  81a5ddadf5879cfd9437ef5b7d0804f2                  0.0        1095.0
# 44523  1ecaea67364c7948a7fc6be4148aa960                  0.0        1855.0
#
#       is_exciting  total_price_including_optional_support date_posted
# 44771         NaN                                  236.78  2014-01-01
# 44520         NaN                                 1777.60  2014-01-01
# 44521         NaN                                  599.88  2014-01-01
# 44522         NaN                                  557.08  2014-01-01
# 44523         NaN                                 1181.47  2014-01-01

# %%
simple_df_train = simple_df[simple_df['is_exciting'].notna()].sort_values(by='date_posted')

# %%
simple_df_train.head()
# Out:
#                                projectid  fully_funded_binary  essay_length  \
# 664097  77558a6eda151deee9a00553f7fccfc7                  1.0        1254.0
# 664096  e139df754a873a62d93daa56acbf8040                  1.0        2272.0
# 664095  82e536f14eadf2671a70e03416f695a3                  1.0        1239.0
# 664094  e02da37beb332eb66c2d2ba989c597ad                  1.0        2271.0
# 664066  17dc6d57a9ae536b08fcd45042dc1efc                  1.0        4335.0
#
#        is_exciting  total_price_including_optional_support date_posted
# 664097           f                                  279.27  2002-09-13
# 664096           f                                  152.44  2002-09-13
# 664095           f                                  152.44  2002-09-16
# 664094           f                                 1376.83  2002-09-17
# 664066           f                                  563.41  2002-09-17

# %%
simple_df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 619326 entries, 664097 to 44772
# Data columns (total 6 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   projectid                               619326 non-null  object
#  1   fully_funded_binary                     619326 non-null  float64
#  2   essay_length                            619323 non-null  float64
#  3   is_exciting                             619326 non-null  object
#  4   total_price_including_optional_support  619326 non-null  float64
#  5   date_posted                             619326 non-null  object
# dtypes: float64(3), object(3)
# memory usage: 33.1+ MB

# %%
simple_df_train.describe(include='all').T
# Out:
#                                            count  unique  \
# projectid                                 619326  619326
# fully_funded_binary                     619326.0     NaN
# essay_length                            619323.0     NaN
# is_exciting                               619326       2
# total_price_including_optional_support  619326.0     NaN
# date_posted                               619326    3894
#
#                                                                      top  \
# projectid                               77558a6eda151deee9a00553f7fccfc7
# fully_funded_binary                                                  NaN
# essay_length                                                         NaN
# is_exciting                                                            f
# total_price_including_optional_support                               NaN
# date_posted                                                   2012-09-30
#
# ...

# %%
simple_df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44772 entries, 44771 to 0
# Data columns (total 6 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   projectid                               44772 non-null  object
#  1   fully_funded_binary                     44772 non-null  float64
#  2   essay_length                            44772 non-null  float64
#  3   is_exciting                             0 non-null      object
#  4   total_price_including_optional_support  44772 non-null  float64
#  5   date_posted                             44772 non-null  object
# dtypes: float64(3), object(3)
# memory usage: 2.4+ MB

# %%
simple_df_test.describe(include='all').T
# Out:
#                                           count unique  \
# projectid                                 44772  44772
# fully_funded_binary                     44772.0    NaN
# essay_length                            44772.0    NaN
# is_exciting                                   0      0
# total_price_including_optional_support  44772.0    NaN
# date_posted                               44772    132
#
#                                                                      top  \
# projectid                               16bf6f4c3c37da1cb2e92ee8ce834510
# fully_funded_binary                                                  NaN
# essay_length                                                         NaN
# is_exciting                                                          NaN
# total_price_including_optional_support                               NaN
# date_posted                                                   2014-03-08
#
# ...

# %% [markdown]
# ### Reset a little bit. I think we need to forget about the Kaggle 'test' set because we won't have outcomes with which to validate them

# %% [markdown]
#  ### Instead, let's take the current train set that has been sequestered (all dates up to 01-01-2014) and split that into a new training and test set

# %%
new_simple = simple_df_train.copy()

# %%
simplest = new_simple[['projectid', 'date_posted', 'fully_funded_binary']]

# %%
simplest.head()
# Out:
#                                projectid date_posted  fully_funded_binary
# 664097  77558a6eda151deee9a00553f7fccfc7  2002-09-13                  1.0
# 664096  e139df754a873a62d93daa56acbf8040  2002-09-13                  1.0
# 664095  82e536f14eadf2671a70e03416f695a3  2002-09-16                  1.0
# 664094  e02da37beb332eb66c2d2ba989c597ad  2002-09-17                  1.0
# 664066  17dc6d57a9ae536b08fcd45042dc1efc  2002-09-17                  1.0

# %%
simplest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 619326 entries, 664097 to 44772
# Data columns (total 3 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   projectid            619326 non-null  object
#  1   date_posted          619326 non-null  object
#  2   fully_funded_binary  619326 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 18.9+ MB

# %%
simplest.describe(include='all').T
# Out:
#                         count  unique                               top  freq  \
# projectid              619326  619326  77558a6eda151deee9a00553f7fccfc7     1
# date_posted            619326    3894                        2012-09-30  1490
# fully_funded_binary  619326.0     NaN                               NaN   NaN
#
#                          mean       std  min  25%  50%  75%  max
# projectid                 NaN       NaN  NaN  NaN  NaN  NaN  NaN
# date_posted               NaN       NaN  NaN  NaN  NaN  NaN  NaN
# fully_funded_binary  0.695406  0.460236  0.0  0.0  1.0  1.0  1.0

# %%
missing_info = simplest.isna().sum().to_frame(name='missing_count')
missing_info['missing_percent'] = (missing_info['missing_count'] / len(simplest)) * 100
missing_info
# Out:
#                      missing_count  missing_percent
# projectid                        0              0.0
# date_posted                      0              0.0
# fully_funded_binary              0              0.0

# %%
simplest['fully_funded_binary'].value_counts()
# Out:
# fully_funded_binary
# 1.0    430683
# 0.0    188643
# Name: count, dtype: int64

# %%
simplest['fully_funded_binary'].value_counts(normalize=True)
# Out:
# fully_funded_binary
# 1.0    0.695406
# 0.0    0.304594
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

# Count the values
counts = simplest['fully_funded_binary'].value_counts().sort_index()

# Plot the bar chart
plt.figure(figsize=(6, 4))
counts.plot(kind='bar', color=['skyblue', 'orange'])
plt.title('Class Balance of Fully Funded Binary')
plt.xlabel('Fully Funded (0 = No, 1 = Yes)')
plt.ylabel('Number of Projects')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
simplest['date_posted'] = pd.to_datetime(simplest['date_posted'])
# Out:
# C:\Users\agspi\AppData\Local\Temp\ipykernel_41496\3450573999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   simplest['date_posted'] = pd.to_datetime(simplest['date_posted'])

# %%
plt.figure(figsize=(10, 5))
plt.hist(simplest['date_posted'], bins=50, color='teal')
plt.title('Histogram of Project Posting Dates')
plt.xlabel('Date Posted')
plt.ylabel('Number of Projects')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
simplest['year'] = simplest['date_posted'].dt.year
simplest['year'].value_counts().sort_index().plot(kind='bar', figsize=(10, 5), color='slateblue')

plt.title('Number of Projects Posted Per Year')
plt.xlabel('Year')
plt.ylabel('Project Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\agspi\AppData\Local\Temp\ipykernel_41496\3040602100.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   simplest['year'] = simplest['date_posted'].dt.year

# %%
# Count number of projects by year and funding status
funding_counts = simplest.groupby(['year', 'fully_funded_binary']).size().unstack(fill_value=0)

# Rename columns for clarity (0 = Not Funded, 1 = Fully Funded)
funding_counts.columns = ['Not Funded', 'Fully Funded']

# Plot
funding_counts.plot(kind='bar', figsize=(10, 6), color=['salmon', 'seagreen'])

plt.title('Number of Projects by Funding Status per Year')
plt.xlabel('Year')
plt.ylabel('Number of Projects')
plt.xticks(rotation=45)
plt.legend(title='Funding Status')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Calculate percentage fully funded per year
percentage_funded = (funding_counts['Fully Funded'] / funding_counts.sum(axis=1)) * 100

# Plot
percentage_funded.plot(kind='bar', figsize=(10, 5), color='mediumturquoise')

plt.title('Percentage of Projects Fully Funded per Year')
plt.xlabel('Year')
plt.ylabel('Percentage Fully Funded')
plt.ylim(0, 100)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
sns.pairplot(simplest)

# %% [markdown]
# ### Let's find an appropriate date to make the train test cutoff split at

# %%
simplest['date_posted'].min(), simplest['date_posted'].max()
# Out:
# (Timestamp('2002-09-13 00:00:00'), Timestamp('2013-12-31 00:00:00'))

# %%
simplest['year'] = simplest['date_posted'].dt.year
simplest['year'].value_counts().sort_index().plot(kind='bar', figsize=(10, 4), title='Projects per Year')
# Out:
# C:\Users\agspi\AppData\Local\Temp\ipykernel_41496\523765652.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   simplest['year'] = simplest['date_posted'].dt.year
# <Axes: title={'center': 'Projects per Year'}, xlabel='year'>

# %% [markdown]
# We see a sharp increase in project volume starting around 2007, with steady, high-volume activity from 2009–2013. Suggests:
#
# Pre-2007: Sparse data, probably too small to be very useful for training.
#
# 2007–2012: Good consistent data for model learning.
#
# 2013: Could be a good cutoff year for testing — it has lots of volume but is still a clean boundary.

# %% [markdown]
# Train set: All data before 2013
#
# Test set: Data in 2013
#
# This gives a realistic forecasting scenario. train on long historical trend, test on the most recent complete year.

# %%
simplest_1 = simplest[['projectid', 'date_posted', 'fully_funded_binary']]

# %%
simplest_1['not_fully_funded'] = simplest_1['fully_funded_binary'].apply(lambda x: 0 if x==1 else 1)

# %%
simplest_1.head()
# Out:
#                                projectid date_posted  fully_funded_binary  \
# 664097  77558a6eda151deee9a00553f7fccfc7  2002-09-13                  1.0
# 664096  e139df754a873a62d93daa56acbf8040  2002-09-13                  1.0
# 664095  82e536f14eadf2671a70e03416f695a3  2002-09-16                  1.0
# 664094  e02da37beb332eb66c2d2ba989c597ad  2002-09-17                  1.0
# 664066  17dc6d57a9ae536b08fcd45042dc1efc  2002-09-17                  1.0
#
#         not_fully_funded
# 664097                 0
# 664096                 0
# 664095                 0
# 664094                 0
# 664066                 0

# %%
simplest_1.drop(columns='fully_funded_binary', inplace=True)

# %%
simplest_1.head().T
# Out:
#                                             664097  \
# projectid         77558a6eda151deee9a00553f7fccfc7
# date_posted                    2002-09-13 00:00:00
# not_fully_funded                                 0
#
#                                             664096  \
# projectid         e139df754a873a62d93daa56acbf8040
# date_posted                    2002-09-13 00:00:00
# not_fully_funded                                 0
#
#                                             664095  \
# projectid         82e536f14eadf2671a70e03416f695a3
# date_posted                    2002-09-16 00:00:00
# not_fully_funded                                 0
#
#                                             664094  \
# projectid         e02da37beb332eb66c2d2ba989c597ad
# date_posted                    2002-09-17 00:00:00
# not_fully_funded                                 0
#
#                                             664066
# projectid         17dc6d57a9ae536b08fcd45042dc1efc
# ...

# %%
simplest_2 = simplest_1.copy()
simplest_2['essay_length'] = df['essay_length']
simplest_2.head().T
# Out:
#                                             664097  \
# projectid         77558a6eda151deee9a00553f7fccfc7
# date_posted                    2002-09-13 00:00:00
# not_fully_funded                                 0
# essay_length                                1254.0
#
#                                             664096  \
# projectid         e139df754a873a62d93daa56acbf8040
# date_posted                    2002-09-13 00:00:00
# not_fully_funded                                 0
# essay_length                                2272.0
#
#                                             664095  \
# projectid         82e536f14eadf2671a70e03416f695a3
# date_posted                    2002-09-16 00:00:00
# not_fully_funded                                 0
# essay_length                                1239.0
#
#                                             664094  \
# projectid         e02da37beb332eb66c2d2ba989c597ad
# date_posted                    2002-09-17 00:00:00
# ...

# %%
simplest_2['school_state'] = df['school_state']

# %%
simplest_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 619326 entries, 664097 to 44772
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   projectid         619326 non-null  object
#  1   date_posted       619326 non-null  datetime64[ns]
#  2   not_fully_funded  619326 non-null  int64
#  3   essay_length      619323 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 23.6+ MB

# %% [markdown]
# ### Decision Tree on Simplest DF

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming your DataFrame is called df and it has columns 'projectid' and 'fully_funded_binary'
le = LabelEncoder()
simplest_1['projectid_encoded'] = le.fit_transform(simplest_1['projectid'])

# Now use this encoded column as your feature
#X = df[['projectid_encoded']]
#y = df['fully_funded_binary']

# %%
simplest_1.head()
# Out:
#                                projectid date_posted  not_fully_funded  \
# 664097  77558a6eda151deee9a00553f7fccfc7  2002-09-13                 0
# 664096  e139df754a873a62d93daa56acbf8040  2002-09-13                 0
# 664095  82e536f14eadf2671a70e03416f695a3  2002-09-16                 0
# 664094  e02da37beb332eb66c2d2ba989c597ad  2002-09-17                 0
# 664066  17dc6d57a9ae536b08fcd45042dc1efc  2002-09-17                 0
#
#         projectid_encoded
# 664097             288752
# 664096             545397
# 664095             316916
# 664094             542829
# 664066              57550

# %%
cutoff_date = '2013-01-01'

train_df_1 = simplest_1[simplest_1['date_posted'] < cutoff_date]
test_df_1 = simplest_1[simplest_1['date_posted'] >= cutoff_date]

print(f"Train size: {len(train_df_1)}")
print(f"Test size: {len(test_df_1)}")
# Out:
# Train size: 487997
# Test size: 131329

# %%
# Use date_posted as numeric feature
X_train_1 = train_df_1[['projectid_encoded']].copy()
X_test_1 = test_df_1[['projectid_encoded']].copy()

# Convert to numeric timestamp
# X_train['date_posted'] = pd.to_datetime(X_train['date_posted']).astype('int64') // 10**9
# X_test['date_posted'] = pd.to_datetime(X_test['date_posted']).astype('int64') // 10**9

# Label
y_train_1 = train_df_1['not_fully_funded']
y_test_1 = test_df_1['not_fully_funded']

# %%
from sklearn.tree import DecisionTreeClassifier

# Instantiate the model with default settings
clf = DecisionTreeClassifier(random_state=42)

# Fit the model
clf.fit(X_train_1, y_train_1)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_1 = clf.predict(X_test_1)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Accuracy
print("Accuracy:", accuracy_score(y_test_1, y_pred_1))

# Confusion Matrix
print("Confusion Matrix:\n", confusion_matrix(y_test_1, y_pred_1))

# Classification Report
print("Classification Report:\n", classification_report(y_test_1, y_pred_1))
# Out:
# Accuracy: 0.580443009540924
# Confusion Matrix:
#  [[64349 28050]
#  [27050 11880]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70     92399
#            1       0.30      0.31      0.30     38930
#
#     accuracy                           0.58    131329
#    macro avg       0.50      0.50      0.50    131329
# weighted avg       0.58      0.58      0.58    131329

# %%
from sklearn.metrics import confusion_matrix

# Get confusion matrix
cm = confusion_matrix(y_test_1, y_pred_1)
tn, fp, fn, tp = cm.ravel()

# Calculate specificity
specificity = tn / (tn + fp)
recall = tp / (tp + fn)
fpr = 1 - specificity

print("Specificity (True Negative Rate):", round(specificity, 3))
print("Recall (True Positive Rate):", round(recall, 3))
print("FPR (1-specificity):", round(fpr, 3))
print('tn:', tn, '\n', 'fp:', fp, '\n', 'fn:', fn, '\n', 'tp:', tp)
# Out:
# Specificity (True Negative Rate): 0.696
# Recall (True Positive Rate): 0.305
# FPR (1-specificity): 0.304
# tn: 64349
#  fp: 28050
#  fn: 27050
#  tp: 11880

# %% [markdown]
# ### Simplest Feature Matrix with Decision Tree Interpretation

# %% [markdown]
# TN = 92399: Model predicted all true 0s correctly (fully funded projects)
#
# FP = 0: Model never predicted 1 — it predicted all samples as 0 or fully funded
#
# FN = 38930: It missed every actual 1
#
# TP = 0: It missed all the actual 1's (i.e. not fully funded projects)

# %% [raw]
# Metric	Class 1 (Not Funded)	Class 0 (Fully Funded)
# Precision	0.00	                0.70
# Recall	    0.00	                1.00
# F1-score	0.00	                0.83

# %% [raw]
# It only predicts "0" (fully funded) for everything
#
# It never attempts to predict a "1", so:
# Recall = 0
# Specificity = 1
#
# The model is just predicting the majority class
# Class imbalance: 70% of the test set is "0", so even a dumb model that says "0" for everything gets 70% accuracy

# %% [raw]
# The model cannot recognize "not funded" projects at all
# It misses every actually positive case (False Negatives = 38930)
# This is a very high Type I error problem if you’re trying to avoid false positives

# %% [raw]
# This model has learned only one thing: everything is "likely to be funded"
#
# That’s likely because date_posted correlates strongly with increased funding in recent years, and your test set (2013) is skewed toward more positive outcomes

# %% [markdown]
# ### Now add a new feature (school_state)

# %%
dummies = pd.get_dummies(simplest_2['school_state'], prefix='school_state')
simplest_2 = pd.concat([simplest_2, dummies], axis=1)

# %%
# For entire DataFrame (affects all bool columns)
simplest_2 = simplest_2.astype({col: 'int' for col in simplest_2.columns if simplest_2[col].dtype == 'bool'})

# %%
cutoff_date = '2013-01-01'

train_df_2 = simplest_2[simplest_2['date_posted'] < cutoff_date]
test_df_2 = simplest_2[simplest_2['date_posted'] >= cutoff_date]

print(f"Train size: {len(train_df_2)}")
print(f"Test size: {len(test_df_2)}")
# Out:
# Train size: 487997
# Test size: 131329

# %%
train_df_2.head()
# Out:
#                                projectid date_posted  not_fully_funded  \
# 664097  77558a6eda151deee9a00553f7fccfc7  2002-09-13                 0
# 664096  e139df754a873a62d93daa56acbf8040  2002-09-13                 0
# 664095  82e536f14eadf2671a70e03416f695a3  2002-09-16                 0
# 664094  e02da37beb332eb66c2d2ba989c597ad  2002-09-17                 0
# 664066  17dc6d57a9ae536b08fcd45042dc1efc  2002-09-17                 0
#
#         essay_length school_state  school_state_AK  school_state_AL  \
# 664097        1254.0           NY                0                0
# 664096        2272.0           NY                0                0
# 664095        1239.0           NY                0                0
# 664094        2271.0           NY                0                0
# 664066        4335.0           NY                0                0
#
#         school_state_AR  school_state_AZ  school_state_CA  ...  \
# ...

# %%
train_df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 487997 entries, 664097 to 176196
# Data columns (total 57 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   projectid         487997 non-null  object
#  1   date_posted       487997 non-null  datetime64[ns]
#  2   not_fully_funded  487997 non-null  int64
#  3   essay_length      487995 non-null  float64
#  4   school_state      487997 non-null  object
#  5   school_state_AK   487997 non-null  int32
#  6   school_state_AL   487997 non-null  int32
#  7   school_state_AR   487997 non-null  int32
#  8   school_state_AZ   487997 non-null  int32
#  9   school_state_CA   487997 non-null  int32
#  10  school_state_CO   487997 non-null  int32
#  11  school_state_CT   487997 non-null  int32
#  12  school_state_DC   487997 non-null  int32
#  13  school_state_DE   487997 non-null  int32
#  14  school_state_FL   487997 non-null  int32
#  15  school_state_GA   487997 non-null  int32
# ...

# %%
feature_cols = ['essay_length'] + [col for col in simplest_2.columns if col.startswith('school_state_')]

# Use date_posted as numeric feature
X_train = train_df_2[feature_cols]
X_test = test_df_2[feature_cols]

# Convert to numeric timestamp
#X_train['date_posted'] = pd.to_datetime(X_train['date_posted']).astype('int64') // 10**9
#X_test['date_posted'] = pd.to_datetime(X_test['date_posted']).astype('int64') // 10**9

# Label
y_train = train_df_2['not_fully_funded']
y_test = test_df_2['not_fully_funded']

# %%
X_train.head()
# Out:
#         essay_length  school_state_AK  school_state_AL  school_state_AR  \
# 664097        1254.0                0                0                0
# 664096        2272.0                0                0                0
# 664095        1239.0                0                0                0
# 664094        2271.0                0                0                0
# 664066        4335.0                0                0                0
#
#         school_state_AZ  school_state_CA  school_state_CO  school_state_CT  \
# 664097                0                0                0                0
# 664096                0                0                0                0
# 664095                0                0                0                0
# 664094                0                0                0                0
# 664066                0                0                0                0
#
#         school_state_DC  school_state_DE  ...  school_state_SD  \
# ...

# %%
# Instantiate the model with default settings
clf = DecisionTreeClassifier(random_state=42)

# Fit the model
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))

# Confusion Matrix
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Classification Report
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6609507420295594
# Confusion Matrix:
#  [[82077 10322]
#  [34205  4725]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.71      0.89      0.79     92399
#            1       0.31      0.12      0.18     38930
#
#     accuracy                           0.66    131329
#    macro avg       0.51      0.50      0.48    131329
# weighted avg       0.59      0.66      0.61    131329

# %%
from sklearn.metrics import confusion_matrix

# Get confusion matrix
cm = confusion_matrix(y_test, y_pred)
tn, fp, fn, tp = cm.ravel()

# Calculate specificity
specificity = tn / (tn + fp)
recall = tp / (tp + fn)
fpr = 1 - specificity

print("Specificity (True Negative Rate):", round(specificity, 3))
print("Recall (True Positive Rate):", round(recall, 3))
print("FPR (1-specificity):", round(fpr, 3))
print('tn:', tn, '\n', 'fp:', fp, '\n', 'fn:', fn, '\n', 'tp:', tp)
# Out:
# Specificity (True Negative Rate): 0.888
# Recall (True Positive Rate): 0.121
# FPR (1-specificity): 0.112
# tn: 82077
#  fp: 10322
#  fn: 34205
#  tp: 4725
