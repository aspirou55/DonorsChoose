# %%
import pandas as pd

# %%
clean = pd.read_csv('TIDY_clean.csv')
# Out:
# C:\Users\agspi\AppData\Local\Temp\ipykernel_44752\40926005.py:1: DtypeWarning: Columns (36,37,38,39,40,41,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   clean = pd.read_csv('TIDY_clean.csv')

# %%
clean.head().T
# Out:
#                                                      0  \
# projectid             316ed8fb3b81402ff6ac8f721bb31192
# teacher_acctid_x      42d43fa6f37314365d08692e08680973
# schoolid              c0e6ce89b244764085691a1b8e28cb81
# school_ncesid                            63627006187.0
# school_latitude                               36.57634
# ...                                                ...
# essay_has_materials                                  0
# essay_has_technology                                 0
# essay_has_books                                      1
# essay_word_count                                   396
# sp500_missing                                        0
#
#                                                      1  \
# projectid             90de744e368a7e4883223ca49318ae30
# teacher_acctid_x      864eb466462bf704bf7a16a585ef296a
# schoolid              d711e47810900c96f26a5d0be30c446d
# school_ncesid                           483702008193.0
# ...

# %%
clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664098 entries, 0 to 664097
# Columns: 105 entries, projectid to sp500_missing
# dtypes: float64(31), int64(33), object(41)
# memory usage: 532.0+ MB

# %%
clean.describe(include='all').T
# Out:
#                          count  unique                               top freq  \
# projectid               664098  664098  316ed8fb3b81402ff6ac8f721bb31192    1
# teacher_acctid_x        664098  249555  787720cc575e3204991b8ca18d312d2b  266
# schoolid                664098   57004  9231edfbd3aa42675e70e69aea8b0a36  944
# school_ncesid         664098.0     NaN                               NaN  NaN
# school_latitude       664098.0     NaN                               NaN  NaN
# ...                        ...     ...                               ...  ...
# essay_has_materials   664098.0     NaN                               NaN  NaN
# essay_has_technology  664098.0     NaN                               NaN  NaN
# essay_has_books       664098.0     NaN                               NaN  NaN
# essay_word_count      664098.0     NaN                               NaN  NaN
# sp500_missing         664098.0     NaN                               NaN  NaN
#
# ...

# %%
clean.columns
# Out:
# Index(['projectid', 'teacher_acctid_x', 'schoolid', 'school_ncesid',
#        'school_latitude', 'school_longitude', 'school_city', 'school_state',
#        'school_zip', 'school_metro',
#        ...
#        'essay_has_students', 'essay_has_classroom', 'essay_has_learning',
#        'essay_has_education', 'essay_has_resources', 'essay_has_materials',
#        'essay_has_technology', 'essay_has_books', 'essay_word_count',
#        'sp500_missing'],
#       dtype='object', length=105)

# %%
new_cols = set()
for i in clean.columns:
    new_cols.add(i)

# %%
old_cols = {'three_or_more_non_teacher_referred_donors', 'school_nlns', 'great_chat', 'eligible_double_your_impact_match', 'essay', 'resource_type', 'students_reached', 'secondary_focus_subject', 'short_description', 'title', 'essay_length', 'school_city', 'total_item_quantity', 'price_per_student', 'need_statement', 'teacher_prefix', 'school_latitude', 'is_exciting', 'school_magnet', 'fully_funded', 'teacher_acctid_y', 'school_district', 'total_item_cost', 'eligible_almost_home_match', 'teacher_referred_count', 'at_least_1_teacher_referred_donor', 'need_statement_length', 'fulfillment_labor_materials', 'school_year_round', 'teacher_ny_teaching_fellow', 'teacher_teach_for_america', 'school_county', 'num_items', 'school_charter_ready_promise', 'at_least_1_green_donation', 'school_longitude', 'school_zip', 'projectid', 'secondary_focus_area', 'primary_focus_subject', 'total_price_excluding_optional_support', 'school_kipp', 'schoolid', 'poverty_level', 'non_teacher_referred_count', 'school_ncesid', 'date_posted', 'teacher_acctid_x', 'has_essay', 'one_non_teacher_referred_donor_giving_100_plus', 'school_metro', 'primary_focus_area', 'grade_level', 'great_messages_proportion', 'avg_donation_amount', 'num_donations', 'unique_vendor_count', 'fully_funded_binary', 'total_donation_amount', 'avg_cost_per_item', 'school_state', 'donation_from_thoughtful_donor', 'sp500_daily_diff', 'school_charter', 'total_price_including_optional_support'}

# %%
new_cols != new_cols
# Out:
# False

# %%
clean['students_reached'].value_counts()
# Out:
# students_reached
# 20.0     50292
# 25.0     45627
# 30.0     37049
# 24.0     25439
# 22.0     24407
#          ...
# 798.0        1
# 711.0        1
# 559.0        1
# 569.0        1
# 696.0        1
# Name: count, Length: 789, dtype: int64

# %%
clean['students_reached'].min()
# Out:
# 0.0
